# %% [markdown]
# # Project: Communicate Data Findings Flights

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
# I have selected custom dataset for my project flights in USA in 2015. I will focus my analysis on flights in state California.
#
# I will be answering following questions:
#
# 1. How many wheels_on passengers were travelling in California?
# 2. What is the rate of wheels_on flights in California?
# 3. Which origin airports have most wheels_on passengers on Monday in state California?
# 4. How many WHEELS_ON passengers flights per month were in California?
#
# This project is divided into two major parts. In the first part, I will conduct an exploratory data analysis on a Flight USA 2015 dataset. I will conduct my analysis in Jupyter notebook using Python and its libraries. I will focus my analysis on California state. There I will look research questions above.
#
# In the second part I will use create a slide deck with several choosen findings.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')


get_ipython().run_line_magic('matplotlib', 'inline')

# %%
# load in the dataset into a pandas dataframe
flights = pd.read_csv('flights.csv')

# %%
# load in the dataset into a pandas dataframe
airports = pd.read_csv('airports.csv')

# %% [markdown]
# <a id='overview'></a>
# ## Dataset Overview
#
# Checking out my dataset.

# %%
# checking flights.csv
print(flights.shape)
print(flights.dtypes)
flights.head(10)
flights.tail(10)
# Out:
# (274964, 34)
# Unnamed: 0               int64
# Unnamed: 0.1             int64
# Unnamed: 0.1.1           int64
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# dtype: object
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  MONTH  DAY  \
# 274954      299988         66749         2306585  2015      5   27
# 274955      299989         92595           58054  2015      1    4
# 274956      299990        512658         2285545  2015      5   25
# 274957      299991        509115          678783  2015      2   14
# 274958      299992        111999         4963454  2015     11    6
# 274959      299993        382116         1484404  2015      4    6
# 274960      299994         75737          942657  2015      3    3
# 274961      299995        249172         3071702  2015      7   12
# 274962      299998        488240         5114407  2015     11   16
# 274963      299999        105711          440188  2015      1   29
#
#         DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  ... ARRIVAL_TIME  \
# 274954            3      F9            708      N943FR  ...       1221.0
# 274955            7      US            467      N665AW  ...       1936.0
# 274956            1      WN           3968      N739GB  ...       2005.0
# 274957            6      WN           2722      N8328A  ...       2016.0
# 274958            5      OO           4556      N8884E  ...       1625.0
# 274959            1      MQ           2946      N662MQ  ...        749.0
# 274960            2      OO           6250      N776SK  ...       1922.0
# 274961            7      DL           2794      N662DN  ...        931.0
# 274962            1      AS            182      N767AS  ...       1505.0
# 274963            4      B6            761      N746JB  ...       2241.0
#
#        ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 274954          -4.0         0          0                  NaN
# 274955          15.0         0          0                  NaN
# 274956         -15.0         0          0                  NaN
# 274957           1.0         0          0                  NaN
# 274958          -9.0         0          0                  NaN
# 274959           8.0         0          0                  NaN
# 274960          70.0         0          0                  NaN
# 274961          11.0         0          0                  NaN
# 274962         -19.0         0          0                  NaN
# 274963          -4.0         0          0                  NaN
#
#         AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 274954               NaN             NaN            NaN                  NaN
# 274955               5.0             0.0            0.0                 10.0
# 274956               NaN             NaN            NaN                  NaN
# 274957               NaN             NaN            NaN                  NaN
# 274958               NaN             NaN            NaN                  NaN
# 274959               NaN             NaN            NaN                  NaN
# 274960              10.0             0.0            0.0                 60.0
# 274961               NaN             NaN            NaN                  NaN
# 274962               NaN             NaN            NaN                  NaN
# 274963               NaN             NaN            NaN                  NaN
#
#         WEATHER_DELAY
# 274954            NaN
# 274955            0.0
# 274956            NaN
# 274957            NaN
# 274958            NaN
# 274959            NaN
# 274960            0.0
# 274961            NaN
# 274962            NaN
# 274963            NaN
#
# [10 rows x 34 columns]

# %%
#checking airports.csv
print(airports.shape)
print(airports.dtypes)
airports.head(10)
airports.tail(10)
# Out:
# (322, 7)
# IATA_CODE     object
# AIRPORT       object
# CITY          object
# STATE         object
# COUNTRY       object
# LATITUDE     float64
# LONGITUDE    float64
# dtype: object
#     IATA_CODE                                            AIRPORT  \
# 312       TYS                               McGhee Tyson Airport
# 313       UST  Northeast Florida Regional Airport (St. August...
# 314       VEL                                     Valdez Airport
# 315       VLD                          Valdosta Regional Airport
# 316       VPS         Destin-Fort Walton Beach Airport/Eglin AFB
# 317       WRG                                   Wrangell Airport
# 318       WYS                             Westerly State Airport
# 319       XNA                Northwest Arkansas Regional Airport
# 320       YAK                                    Yakutat Airport
# 321       YUM                         Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 312                       Knoxville    TN     USA  35.81249  -83.99286
# 313                   St. Augustine    FL     USA       NaN        NaN
# 314                          Vernal    UT     USA  40.44090 -109.50992
# 315                        Valdosta    GA     USA  30.78250  -83.27672
# 316                      Valparaiso    FL     USA  30.48325  -86.52540
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597

# %%
#joining 2 csv datasts together
originair_flights = pd.merge(left=flights, right=airports, how='left', left_on='ORIGIN_AIRPORT', right_on='IATA_CODE')
originair_flights.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  MONTH  DAY  DAY_OF_WEEK  \
# 0           0        363169         5290975  2015     11   28            6
# 1           1        704061         4899614  2015     11    2            1
# 2           2        389056         3769408  2015      8   22            6
# 3           3        132167         4999624  2015     11    9            1
# 4           4        304371         2572568  2015      6   12            5
#
#   AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  ... AIRLINE_DELAY LATE_AIRCRAFT_DELAY  \
# 0      DL           1590      N971AT  ...           NaN                 NaN
# 1      AA           2516      N3CVAA  ...          28.0                 0.0
# 2      AS             93      N317AS  ...           NaN                 NaN
# 3      AA           2383      N871AA  ...           NaN                 NaN
# 4      US           1978      N833AW  ...           NaN                 NaN
#
#    WEATHER_DELAY  IATA_CODE                                  AIRPORT  \
# 0            NaN        CAE            Columbia Metropolitan Airport
# 1            0.0        ORD     Chicago O'Hare International Airport
# 2            NaN        SEA     Seattle-Tacoma International Airport
# 3            NaN        MCO            Orlando International Airport
# 4            NaN        CLE  Cleveland Hopkins International Airport
#
#         CITY  STATE  COUNTRY  LATITUDE  LONGITUDE
# 0   Columbia     SC      USA  33.93884  -81.11954
# 1    Chicago     IL      USA  41.97960  -87.90446
# 2    Seattle     WA      USA  47.44898 -122.30931
# 3    Orlando     FL      USA  28.42889  -81.31603
# 4  Cleveland     OH      USA  41.41089  -81.84940
#
# [5 rows x 41 columns]

# %%
print(originair_flights.shape)
print(originair_flights.dtypes)
originair_flights.head(10)
originair_flights.tail(10)
# Out:
# (274964, 41)
# Unnamed: 0               int64
# Unnamed: 0.1             int64
# Unnamed: 0.1.1           int64
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# IATA_CODE               object
# AIRPORT                 object
# CITY                    object
# STATE                   object
# COUNTRY                 object
# LATITUDE               float64
# LONGITUDE              float64
# dtype: object
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  MONTH  DAY  \
# 274954      299988         66749         2306585  2015      5   27
# 274955      299989         92595           58054  2015      1    4
# 274956      299990        512658         2285545  2015      5   25
# 274957      299991        509115          678783  2015      2   14
# 274958      299992        111999         4963454  2015     11    6
# 274959      299993        382116         1484404  2015      4    6
# 274960      299994         75737          942657  2015      3    3
# 274961      299995        249172         3071702  2015      7   12
# 274962      299998        488240         5114407  2015     11   16
# 274963      299999        105711          440188  2015      1   29
#
#         DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  ... AIRLINE_DELAY  \
# 274954            3      F9            708      N943FR  ...           NaN
# 274955            7      US            467      N665AW  ...           0.0
# 274956            1      WN           3968      N739GB  ...           NaN
# 274957            6      WN           2722      N8328A  ...           NaN
# 274958            5      OO           4556      N8884E  ...           NaN
# 274959            1      MQ           2946      N662MQ  ...           NaN
# 274960            2      OO           6250      N776SK  ...           0.0
# 274961            7      DL           2794      N662DN  ...           NaN
# 274962            1      AS            182      N767AS  ...           NaN
# 274963            4      B6            761      N746JB  ...           NaN
#
#        LATE_AIRCRAFT_DELAY  WEATHER_DELAY  IATA_CODE  \
# 274954                 NaN            NaN        DEN
# 274955                10.0            0.0        EWR
# 274956                 NaN            NaN        BWI
# 274957                 NaN            NaN        BNA
# 274958                 NaN            NaN        DTW
# 274959                 NaN            NaN        LCH
# 274960                60.0            0.0        ASE
# 274961                 NaN            NaN        DTW
# 274962                 NaN            NaN        ANC
# 274963                 NaN            NaN        LGA
#
#                                             AIRPORT          CITY  STATE  \
# 274954                 Denver International Airport        Denver     CO
# 274955         Newark Liberty International Airport        Newark     NJ
# 274956   Baltimore-Washington International Airport     Baltimore     MD
# 274957              Nashville International Airport     Nashville     TN
# 274958                 Detroit Metropolitan Airport       Detroit     MI
# 274959                Lake Charles Regional Airport  Lake Charles     LA
# 274960                  Aspen-Pitkin County Airport         Aspen     CO
# 274961                 Detroit Metropolitan Airport       Detroit     MI
# 274962  Ted Stevens Anchorage International Airport     Anchorage     AK
# 274963      LaGuardia Airport (Marine Air Terminal)      New York     NY
#
#         COUNTRY  LATITUDE  LONGITUDE
# 274954      USA  39.85841 -104.66700
# 274955      USA  40.69250  -74.16866
# 274956      USA  39.17540  -76.66820
# 274957      USA  36.12448  -86.67818
# 274958      USA  42.21206  -83.34884
# 274959      USA  30.12610  -93.22340
# 274960      USA  39.22316 -106.86885
# 274961      USA  42.21206  -83.34884
# 274962      USA  61.17432 -149.99619
# 274963      USA  40.77724  -73.87261
#
# [10 rows x 41 columns]

# %%
#dropping columns I will not need for my analysis
originair_flights.drop(["TAIL_NUMBER","SCHEDULED_DEPARTURE","DEPARTURE_TIME","DISTANCE","AIR_TIME","DEPARTURE_TIME","TAXI_OUT","SCHEDULED_ARRIVAL","TAXI_IN","SECURITY_DELAY","AIRLINE_DELAY","AIR_SYSTEM_DELAY","CANCELLATION_REASON","LATE_AIRCRAFT_DELAY"], axis=1, inplace=True)

# %%
originair_flights.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  MONTH  DAY  DAY_OF_WEEK  \
# 0           0        363169         5290975  2015     11   28            6
# 1           1        704061         4899614  2015     11    2            1
# 2           2        389056         3769408  2015      8   22            6
# 3           3        132167         4999624  2015     11    9            1
# 4           4        304371         2572568  2015      6   12            5
#
#   AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  ... DIVERTED  CANCELLED  \
# 0      DL           1590            CAE  ...        0          0
# 1      AA           2516            ORD  ...        0          0
# 2      AS             93            SEA  ...        0          0
# 3      AA           2383            MCO  ...        0          0
# 4      US           1978            CLE  ...        0          0
#
#    WEATHER_DELAY  IATA_CODE                                  AIRPORT  \
# 0            NaN        CAE            Columbia Metropolitan Airport
# 1            0.0        ORD     Chicago O'Hare International Airport
# 2            NaN        SEA     Seattle-Tacoma International Airport
# 3            NaN        MCO            Orlando International Airport
# 4            NaN        CLE  Cleveland Hopkins International Airport
#
#         CITY  STATE  COUNTRY  LATITUDE  LONGITUDE
# 0   Columbia     SC      USA  33.93884  -81.11954
# 1    Chicago     IL      USA  41.97960  -87.90446
# 2    Seattle     WA      USA  47.44898 -122.30931
# 3    Orlando     FL      USA  28.42889  -81.31603
# 4  Cleveland     OH      USA  41.41089  -81.84940
#
# [5 rows x 28 columns]

# %% [markdown]
# Most of the data is filled out, we can see that WEATHER_DELAY has many NaN values.

# %%
originair_flights.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1  Unnamed: 0.1.1      YEAR          MONTH  \
# count  274964.000000  274964.000000    2.749640e+05  274964.0  274964.000000
# mean   150050.684421  374262.390051    2.752583e+06    2015.0       6.207376
# std     86596.045375  216469.350530    1.670198e+06       0.0       3.388097
# min         0.000000       0.000000    4.100000e+01    2015.0       1.000000
# 25%     75104.750000  186536.500000    1.330938e+06    2015.0       3.000000
# 50%    150178.500000  374015.500000    2.666302e+06    2015.0       6.000000
# 75%    224995.250000  561742.500000    4.002737e+06    2015.0       9.000000
# max    299999.000000  749999.000000    5.819057e+06    2015.0      12.000000
#
#                  DAY    DAY_OF_WEEK  FLIGHT_NUMBER  DEPARTURE_DELAY  \
# count  274964.000000  274964.000000  274964.000000    270719.000000
# mean       15.667869       3.925081    2180.364186         9.786749
# std         8.767596       1.992091    1759.360935        37.635842
# min         1.000000       1.000000       1.000000       -56.000000
# 25%         8.000000       2.000000     732.000000        -5.000000
# 50%        16.000000       4.000000    1691.000000        -1.000000
# 75%        23.000000       6.000000    3262.000000         8.000000
# max        31.000000       7.000000    7438.000000      1461.000000
#
#           WHEELS_OFF  SCHEDULED_TIME   ELAPSED_TIME      WHEELS_ON  \
# count  270571.000000   274964.000000  269773.000000  270377.000000
# mean     1358.546795      141.513973     136.955715    1470.581721
# std       498.664830       75.157110      74.231113     524.027834
# min         1.000000       18.000000      16.000000       1.000000
# 25%       937.000000       85.000000      82.000000    1054.000000
# 50%      1344.000000      122.000000     118.000000    1508.000000
# 75%      1755.000000      173.000000     168.000000    1911.000000
# max      2400.000000      718.000000     726.000000    2400.000000
#
#         ARRIVAL_TIME  ARRIVAL_DELAY       DIVERTED      CANCELLED  \
# count  270377.000000  269773.000000  274964.000000  274964.000000
# mean     1475.626570       4.902333       0.002757       0.016122
# std       528.119405      39.780979       0.052432       0.125945
# min         1.000000     -87.000000       0.000000       0.000000
# 25%      1058.000000     -13.000000       0.000000       0.000000
# 50%      1512.000000      -5.000000       0.000000       0.000000
# 75%      1916.000000       8.000000       0.000000       0.000000
# max      2400.000000    1455.000000       1.000000       1.000000
#
#        WEATHER_DELAY       LATITUDE      LONGITUDE
# count   51863.000000  274703.000000  274703.000000
# mean        3.158591      36.647905     -95.480777
# std        22.569128       5.980915      18.124967
# min         0.000000      13.483450    -176.646030
# 25%         0.000000      32.895950    -111.977770
# 50%         0.000000      37.361860     -90.258030
# 75%         0.000000      40.788390     -81.687860
# max      1120.000000      71.285450     -64.798560

# %% [markdown]
# I decided to focus my analysis on only state - California.

# %%
mask = originair_flights["STATE"].isin(["CA"])   
#I made a copy to handle error of chained indexing
airCA = originair_flights[mask].copy()
airCA.head()
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  YEAR  MONTH  DAY  DAY_OF_WEEK  \
# 6            6        179324         3704124  2015      8   18            2
# 30          31        650240         2619628  2015      6   15            1
# 35          37        609389         1225475  2015      3   21            6
# 38          40        725217         4061683  2015      9   10            4
# 49          51        514150         5030381  2015     11   10            2
#
#    AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  ... DIVERTED  CANCELLED  \
# 6       OO           5538            SFO  ...        0          0
# 30      WN            260            LAX  ...        0          0
# 35      AA           1462            ONT  ...        0          0
# 38      WN           2590            SFO  ...        0          0
# 49      DL           1792            SAN  ...        0          0
#
#     WEATHER_DELAY  IATA_CODE  \
# 6             0.0        SFO
# 30            NaN        LAX
# 35            NaN        ONT
# 38            NaN        SFO
# 49            NaN        SAN
#
#                                               AIRPORT           CITY  STATE  \
# 6                 San Francisco International Airport  San Francisco     CA
# 30                  Los Angeles International Airport    Los Angeles     CA
# 35                      Ontario International Airport        Ontario     CA
# 38                San Francisco International Airport  San Francisco     CA
# 49  San Diego International Airport (Lindbergh Field)      San Diego     CA
#
#     COUNTRY  LATITUDE  LONGITUDE
# 6       USA  37.61900 -122.37484
# 30      USA  33.94254 -118.40807
# 35      USA  34.05600 -117.60119
# 38      USA  37.61900 -122.37484
# 49      USA  32.73356 -117.18966
#
# [5 rows x 28 columns]

# %%
#check for duplicated values
sum(airCA.duplicated()) #0 means no duplicate values
# Out:
# 0

# %% [markdown]
# ## Exploration of wheels_on passengers in California state in year 2015
#
# I will explore flights in California state. I am also interested how many wheels_on passengers are on these flights.

# %% [markdown]
# ### How many wheels_on passengers per month were in California?

# %%
airCA.groupby('MONTH')['WHEELS_ON'].sum().plot(kind = 'line', figsize = (16, 8), color = 'b')
plt.title('Sum wheels_on per month on origin airports in California', fontsize = 14 )
#plt.xlabel('MONTH', fontsize = 14)
plt.ylabel('WHEELS_ON', fontsize = 14)
width = 1
bins = np.arange(1, 14, width)
months_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(1,max(bins),width), months_names);

# %% [markdown]
# We can see declination of wheels_on passengers in February - there were travelling only a little more than 4 million passengers. Highest number of wheels_on passengers was in August, there were almost 4.8 million in total.

# %% [markdown]
# ### Which origin airports have most wheels_on passengers on Monday in state California?

# %%
sub_airCA = airCA.query('DAY_OF_WEEK==1')[col].sort_values('WHEELS_ON', ascending = False)
sub_airCA.groupby('ORIGIN_AIRPORT')['WHEELS_ON'].sum().plot(kind = 'bar', figsize = (16, 8), color = 'b')
plt.title('Sum wheels_on per ORIGIN_AIRPORTS on Monday in California', fontsize = 14 )
plt.xlabel('ORIGIN_AIRPORT', fontsize = 14)
plt.ylabel('WHEELS_ON', fontsize = 14);

# %% [markdown]
# Origin airports with most wheels_on passenger on all Mondays in 2015 in California were LAX and SFO.

# %% [markdown]
# ### Which origin airports have most wheels_on passengers on Saturday in state California?

# %%
sub_airCA = airCA.query('DAY_OF_WEEK==6')[col].sort_values('WHEELS_ON', ascending = False)
sub_airCA.groupby('ORIGIN_AIRPORT')['WHEELS_ON'].sum().plot(kind = 'bar', figsize = (16, 8), color = 'b')
plt.title('Sum wheels_on per ORIGIN_AIRPORTS on Saturday in California', fontsize = 14 )
plt.xlabel('ORIGIN_AIRPORT', fontsize = 14)
plt.ylabel('WHEELS_ON', fontsize = 14);

# %% [markdown]
# Origin airports with most wheels_on passenger on all Saturdays in 2015 in California were LAX and SFO.

# %% [markdown]
# ### How many wheels_on passengers per month were in state California?

# %%
sb.regplot(data = airCA, x = 'MONTH', y = 'WHEELS_ON',fit_reg = False, 
          x_jitter = 0.2, y_jitter = 0.2, scatter_kws = {'alpha' : 1/20})
plt.title('Different no. of wheels_on per MONTH in year 2015 in California', fontsize = 14 )
plt.xlabel('MONTH', fontsize = 14)
plt.ylabel('WHEELS_ON', fontsize = 14);
width = 1
bins = np.arange(1, 14, width)
months_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(np.arange(1,max(bins),width), months_names);

# %% [markdown]
# Every month there are flying from 500 to 2400 whells_on passengers with airlines in California.

# %% [markdown]
# ### Which origin airports in California that have  most and least wheels_on passengers in year 2015?

# %%
#I will inspect following columns
col = ['ORIGIN_AIRPORT','MONTH', 'DAY_OF_WEEK', 'WHEELS_ON']

airCA.groupby('ORIGIN_AIRPORT')['WHEELS_ON'].sum().plot(kind = 'bar', figsize = (16, 8), color = 'b')
plt.title('origin airports in California that have most and least wheels_on passengers in 1 year', fontsize = 14 )
plt.xlabel('MONTH', fontsize = 14)
plt.ylabel('WHEELS_ON', fontsize = 14);

# %% [markdown]
# Origin_airports with most wheels_on passengers is LAX and least wheels_on passengers are ACV, RDD and SMX.
